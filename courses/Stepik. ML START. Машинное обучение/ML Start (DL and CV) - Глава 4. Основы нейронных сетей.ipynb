# %% [markdown]
# ### Идея рекуррентных нейронных сетей в том, что выходы снова могут подаваться на входы слоев нейронной сети

# %% [markdown]
# ![image.png](attachment:223dda48-ec17-459c-9f35-5349b644fbec.png)

# %% [markdown]
# ### Функции активации

# %% [markdown]
# ![image.png](attachment:e4f811ad-7210-4b35-93fb-61e7ce476e95.png)

# %% [markdown]
# ### Сверточные слои находящиеся в начале сети извлекают низкоуровневые признаки (линии, окружности), а в конце - высокоуровневые (колеса, фары)

# %% [markdown]
# ![image.png](attachment:4b267664-5331-4e3e-9578-1a2a95fe9dcd.png)

# %% [markdown]
# ### У YOLO есть своя функция потерь - yolo loss

# %% [markdown]
# ![image.png](attachment:5bad4ef9-5a69-4be6-87cf-6c0bcdbe3599.png)

# %% [markdown]
# # Основы PyTorch

# %% [markdown]
# ![image.png](attachment:56178a93-5a70-4a8f-994c-6ff1a38fd56a.png)

# %% [markdown]
# ![image.png](attachment:795587d2-6b17-46f3-ac5e-9e8299a072d2.png)
