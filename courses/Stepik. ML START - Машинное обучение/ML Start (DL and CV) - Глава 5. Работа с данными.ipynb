# %% [markdown]
# ![image.png](attachment:ebac80fa-e43a-4b8b-8f99-190c55eb3820.png)
# ### Даже с самым лучшим алгоритмом не построить хорошую модель для решения задачи, если данные у нас плохие

# %% [markdown]
# ### В любом проекте должно быть техническое ТЗ! Нужно как можно больше данных, чтобы не было необходимости в последующей переразметке

# %% [markdown]
# ### Для создания видео в роли обучающей выборке, рекомендуется делать его длиной 5-60 минут

# %% [markdown]
# ![image.png](attachment:114e3212-af1a-4c0c-bd8e-12d361da9f0c.png)

# %% [markdown]
# ### Shortcut может удалять из видео не нужные объекты, например, когда не кадрах нет необходимого объекта

# %% [markdown]
# # CVAT (Computer Vision Annotation Tool)
# ![image.png](attachment:d15cd97a-d4d7-4785-bc3d-91751a41957e.png)

# %% [markdown]
# ![image.png](attachment:a830fddf-20f8-41ee-aac4-f01b3c4d7673.png)
# ![image.png](attachment:510d5fbf-1d49-4374-be61-316fb4c9e8f0.png)

# %% [markdown]
# ### При разметке объекта захватывать его полностью, не обрезая. После разметки джобы, его проверяют на корректность
