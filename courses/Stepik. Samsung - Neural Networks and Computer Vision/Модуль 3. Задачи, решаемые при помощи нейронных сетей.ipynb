# %% [markdown]
# # Урок 3.1 Бинарная классификация? Бинарная кросс-энтропия!

# %% [markdown]
# ![image.png](attachment:dd6ea492-afe8-4453-bff1-a474179e7562.png)

# %% [markdown]
# ### Сигмоида от выхода сети позволяет получить вероятность принадлежности к классу

# %% [markdown]
# ![image.png](attachment:04e909c5-f2bf-478d-b683-ff66ff21b766.png)

# %% [markdown]
# ![image.png](attachment:b240223a-089d-4756-956c-ba587ba41cd5.png)

# %% [markdown]
# ![image.png](attachment:89af595a-cdfe-4374-a81e-e63f1e380d91.png)
# ### Функция потерь MSE плохо подходит для задач бинарной классификации (особенно с сигмоидной функцией акцивации на последнем слое), т.к. обучая такую нейронную сеть методом градиентного спуска можно столкнуться с нулевыми значениями если значение сигмоиды будет близким к нулю

# %% [markdown]
# ![image.png](attachment:d931161a-e8e0-4c8d-94fe-d717d75fecd2.png)

# %% [markdown]
# ![image.png](attachment:1d27b326-4f81-4154-853c-e9eef5de2e86.png)

# %% [markdown]
# ![image.png](attachment:77ba4c79-1922-494d-a32f-fcc36377432c.png)

# %% [markdown]
# # Урок 3.4 Теоретические задачи: Функции потерь

# %% [markdown]
# ![image.png](attachment:69433c07-3019-4c63-94b2-32b441bcf81b.png)
# ![image.png](attachment:b5211e62-e3c3-4cae-981a-2580e1c22a49.png)

# %% [markdown]
# ![image.png](attachment:9b7aa71c-2841-4c72-9716-9051cce5a21e.png)
# ![image.png](attachment:354a4ba7-7bf2-4239-a90f-a37a53acd237.png)
# ![image.png](attachment:7c173809-6a60-42c7-986f-c19341e3e609.png)
# ![image.png](attachment:9ca6c628-beb7-42d5-9215-8d97f23ca5b0.png)

# %% [markdown]
# ![image.png](attachment:dcbccf3c-03c2-46f3-a6f9-0b7f4ff3c867.png)
# ![image.png](attachment:e81e86d5-1fb3-451f-81dd-d41d51d4d391.png)

# %% [markdown]
# ![image.png](attachment:0ac9270a-b996-40ab-a62d-fe6b61388fdf.png)
