# %% [markdown]
# ![image.png](attachment:4af6291f-906d-448c-88e7-3b55a2a785cf.png)

# %% [markdown]
# ![image.png](attachment:1b40b73d-01ae-4eeb-af82-e3f172c3b4ca.png)

# %% [markdown]
# ![image.png](attachment:1c4ef26a-f48e-4327-b7a8-9009f1c9a974.png)

# %% [markdown]
# ![image.png](attachment:87596616-76b8-4a97-8a92-94d75d6430e7.png)
