# %% [markdown]
# ![image.png](attachment:b0897b90-4021-43ca-95b7-9145d86635cb.png)

# %% [markdown]
# ![image.png](attachment:fa113665-9343-4406-be33-f87d5fb9f0e1.png)

# %% [markdown]
# ### Эпоха - это время за которое весь датасет (все батчи = порции данных) пройдут по всей нейросети

# %% [markdown]
# ### Размер батча должен быть кратен двойке (равен двойке в некоторой степени)

# %% [markdown]
# ![image.png](attachment:77b2bbe6-2a59-4aa0-b189-1dafe487b109.png)
