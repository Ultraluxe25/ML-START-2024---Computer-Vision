# %% [markdown]
# ![image.png](attachment:249c01a5-42e4-4c66-9d4f-7b839d1e6291.png)

# %%
import os

# %% [markdown]
# ### Attributes and methods

# %%
print(dir(os))
# Out:
# ['DirEntry', 'EX_OK', 'F_OK', 'GenericAlias', 'Mapping', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_AddedDllDirectory', '_Environ', '__all__', '__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_walk', '_wrap_close', 'abc', 'abort', 'access', 'add_dll_directory', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsync', 'ftruncate', 
# ...

# %%
print(os.getcwd())
# Out:
# C:\Multimedia\Jupyter Notebooks\ML START 2024\Additional materials

# %%
os.chdir('C:\Multimedia\Jupyter Notebooks')
os.getcwd()
# Out:
# 'C:\\Multimedia\\Jupyter Notebooks'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'AI Academy',
#  'AWS',
#  'Books',
#  'Coursera',
#  'CV ИФП',
#  'Deep-Learning-School-anthology',
#  'DVC',
#  'Easy Offer (Data Scientist - part 1).ipynb',
#  'Great Learning',
#  'Hugging Face',
#  'IBM',
#  'ICPC 2024.ipynb',
#  'IT Academy - Data Science',
#  'Kaggle Courses',
#  'Karpov.Courses',
#  'LeetCode',
#  'Lesta Games подготовка к собесу на Data Scientist.ipynb',
#  'ML START 2024',
#  'Neo4j Fundamentals.ipynb',
#  'Open Data Science',
#  'OpenEdu',
#  'Python Backend - Junior, Middle, Senior.ipynb',
#  'Pytorch by Leopard School.ipynb',
#  'Rolling Scopes School',
#  'Sergey Balakirev',
#  'Sirius courses',
#  'Skill UP Simplilearn',
#  'Stepik',
#  'Teach-in',
#  'Time Series with Coursera and Simplilearn.ipynb',
#  'VK',
#  'Андрей Созыкин - Computer vision (TensorFlow, Keras)',
#  'Андрей Созыкин - NLP',
#  'Быстрый старт в искусственный интеллект',
#  'Дискретная математика (ЛЭТИ)',
#  'Евгений Разинков.ipynb',
#  'ОИПИ',
# ...

# %%
os.mkdir('Train')

# %%
# Only one folder without subfolders
os.rmdir('Train')

# %% [markdown]
# ### Create subdirectories

# %%
os.makedirs('Train\Val\Test')

# %% [markdown]
# ### Remove all folders through the path

# %%
os.getcwd()
# Out:
# 'C:\\Multimedia\\Jupyter Notebooks'

# %%
os.removedirs('Train\Val\Test')

# %%
os.rename('ICPC 2024.ipynb', 'ICPC 2024 (BSU).ipynb')
# os.rename('ICPC 2024 (BSU).ipynb', 'ICPC 2024.ipynb')
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'AI Academy',
#  'AWS',
#  'Books',
#  'Coursera',
#  'CV ИФП',
#  'Deep-Learning-School-anthology',
#  'DVC',
#  'Easy Offer (Data Scientist - part 1).ipynb',
#  'Great Learning',
#  'Hugging Face',
#  'IBM',
#  'ICPC 2024.ipynb',
#  'IT Academy - Data Science',
#  'Kaggle Courses',
#  'Karpov.Courses',
#  'LeetCode',
#  'Lesta Games подготовка к собесу на Data Scientist.ipynb',
#  'ML START 2024',
#  'Neo4j Fundamentals.ipynb',
#  'Open Data Science',
#  'OpenEdu',
#  'Python Backend - Junior, Middle, Senior.ipynb',
#  'Pytorch by Leopard School.ipynb',
#  'Rolling Scopes School',
#  'Sergey Balakirev',
#  'Sirius courses',
#  'Skill UP Simplilearn',
#  'Stepik',
#  'Teach-in',
#  'Time Series with Coursera and Simplilearn.ipynb',
#  'VK',
#  'Андрей Созыкин - Computer vision (TensorFlow, Keras)',
#  'Андрей Созыкин - NLP',
#  'Быстрый старт в искусственный интеллект',
#  'Дискретная математика (ЛЭТИ)',
#  'Евгений Разинков.ipynb',
#  'ОИПИ',
# ...

# %% [markdown]
# ### Time of creation

# %%
os.stat('IBM')
# Out:
# os.stat_result(st_mode=16895, st_ino=31525197391873617, st_dev=1745723514, st_nlink=1, st_uid=0, st_gid=0, st_size=4096, st_atime=1732293110, st_mtime=1723475042, st_ctime=1723042643)

# %%
from datetime import datetime

print(datetime.fromtimestamp(os.stat('IBM').st_mtime))
# Out:
# 2024-08-12 18:04:02.678229

# %% [markdown]
# ### Folders (files) hierarchy

# %%
os.walk(os.getcwd())
# Out:
# <generator object _walk at 0x000001DB06973850>

# %%
for dirpath, dirnames, filenames in os.walk(os.getcwd()):
    print('Current path: ', dirpath)
    print('Directories: ', dirnames)
    print(f'Files: {filenames}\n')
# Out:
# Current path:  C:\Multimedia\Jupyter Notebooks
# Directories:  ['.ipynb_checkpoints', 'AI Academy', 'AWS', 'Books', 'Coursera', 'CV ИФП', 'Deep-Learning-School-anthology', 'DVC', 'Great Learning', 'Hugging Face', 'IBM', 'IT Academy - Data Science', 'Kaggle Courses', 'Karpov.Courses', 'LeetCode', 'ML START 2024', 'Open Data Science', 'OpenEdu', 'Rolling Scopes School', 'Sergey Balakirev', 'Sirius courses', 'Skill UP Simplilearn', 'Stepik', 'Teach-in', 'VK', 'Андрей Созыкин - Computer vision (TensorFlow, Keras)', 'Андрей Созыкин - NLP', 'Быстрый старт в искусственный интеллект', 'Дискретная математика (ЛЭТИ)', 'ОИПИ', 'Функциональный анализ', 'Яндекс']
# ...

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPCODE_VM_OPTIONS': 'C:\\Program Files\\JetBrains\\Activate\\vmoptions\\appcode.vmoptions',
#         'APPDATA': 'C:\\Users\\ultra\\AppData\\Roaming',
#         'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey',
#         'CHOCOLATEYLASTPATHUPDATE': '133592882047156949',
#         'CLION_VM_OPTIONS': 'C:\\Program Files\\JetBrains\\Activate\\vmoptions\\clion.vmoptions',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'ULTRALUXE',
#         'COMSPEC': 'C:\\windows\\system32\\cmd.exe',
#         'DATAGRIP_VM_OPTIONS': 'C:\\Program Files\\JetBrains\\Activate\\vmoptions\\datagrip.vmoptions',
#         'DATASPELL_VM_OPTIONS': 'C:\\Program Files\\JetBrains\\Activate\\vmoptions\\dataspell.vmoptions',
# ...

# %%
print(os.environ.get('HOMEPATH'))
# Out:
# \Users\ultra

# %% [markdown]
# ### Join in OS module

# %%
os.path.join(os.environ['HOMEPATH'], 'text.txt')
# Out:
# '\\Users\\ultra\\text.txt'

# %%
os.path.split(os.environ['HOMEPATH'])
# Out:
# ('\\Users', 'ultra')

# %%
os.path.isdir('\\Users')
# Out:
# True

# %%
dir(os.path)
# Out:
# ['_LCMAP_LOWERCASE',
#  '_LCMapStringEx',
#  '_LOCALE_NAME_INVARIANT',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_abspath_fallback',
#  '_get_bothseps',
#  '_getfinalpathname',
#  '_getfinalpathname_nonstrict',
#  '_getfullpathname',
#  '_getvolumepathname',
#  '_nt_readlink',
#  '_path_normpath',
#  '_readlink_deep',
#  'abspath',
#  'altsep',
#  'basename',
#  'commonpath',
#  'commonprefix',
#  'curdir',
#  'defpath',
#  'devnull',
#  'dirname',
#  'exists',
#  'expanduser',
#  'expandvars',
#  'extsep',
#  'genericpath',
#  'getatime',
#  'getctime',
#  'getmtime',
#  'getsize',
#  'isabs',
#  'isdir',
#  'isfile',
#  'islink',
#  'ismount',
#  'join',
#  'lexists',
#  'normcase',
#  'normpath',
#  'os',
#  'pardir',
#  'pathsep',
#  'realpath',
#  'relpath',
#  'samefile',
#  'sameopenfile',
#  'samestat',
#  'sep',
#  'split',
#  'splitdrive',
#  'splitext',
#  'stat',
# ...
