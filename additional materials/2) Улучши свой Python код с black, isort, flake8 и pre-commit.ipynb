# %% [markdown]
# ![image.png](attachment:6c76b7b2-1ecd-4401-a622-ed8ca3f7ea69.png)

# %%
# !pip install -q black

# %% [markdown]
# ![image.png](attachment:f1a60c04-5fe6-4a11-84e3-f9b9c6744a14.png)

# %% [markdown]
# ![image.png](attachment:1296d5c8-8b41-4296-8656-c6c6100accb2.png)

# %% [markdown]
# ![image.png](attachment:ea039473-2d98-4738-88c5-159b22d7db71.png)

# %%
# !pip install -q isort

# %% [markdown]
# ![image.png](attachment:faf6f804-8d08-4e23-8b92-4533789d4228.png)

# %% [markdown]
# ![image.png](attachment:fa41a6ea-57c1-47a4-9b9e-dcc8ef06c950.png)

# %% [markdown]
# ### Первый файл форматирует весь код целиком, а второй импорты

# %% [markdown]
# ![image.png](attachment:1885bbef-acb9-498e-8b65-1445ce96c6a2.png)

# %%
# !pip install -q flake8
